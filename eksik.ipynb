# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    "yas": [22, 35, np.nan, 28, np.nan],
    "gelir": [2000, 5000, 3000, 4000, 4500]
})

df
# Out:
#     yas  gelir
# 0  22.0   2000
# 1  35.0   5000
# 2   NaN   3000
# 3  28.0   4000
# 4   NaN   4500

# %%
df["yas"].mean()
# Out:
# 28.333333333333332
